# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter

count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_answer, evaluate_retrieval
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from evaluation.eval import evaluate_answer, evaluate_retrieval
#
# File c:\Users\Pazzucconibt\REPO\llm_engineering\week5\evaluation\eval.py:8
#       5 from dotenv import load_dotenv
#       7 from evaluation.test import TestQuestion, load_tests
# ----> 8 from implementation.answer import answer_question, fetch_context
#      11 load_dotenv(override=True)
#      13 MODEL = "gpt-4.1-nano"
#
# File c:\Users\Pazzucconibt\REPO\llm_engineering\week5\implementation\answer.py:19
#      16 DB_NAME = str(Path(__file__).parent.parent / 'vector_db')
#      18 # embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# ---> 19 embeddings = OpenAIEmbeddings(model='text-embedding-3-large')
#      20 RETRIEVAL_K = 10
#      22 SYSTEM_PROMPT = """
#      23 You are a knowledgeable, friendly assistant representing the company Insurellm.
#      24 You are chatting with a user about Insurellm.
#    (...)     28 {context}
#      29 """
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\Pazzucconibt\REPO\llm_engineering\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:366, in OpenAIEmbeddings.validate_environment(self)
#     361         self.http_async_client = httpx.AsyncClient(proxy=self.openai_proxy)
#     362     async_specific = {
#     363         "http_client": self.http_async_client,
#     364         "api_key": async_api_key_value,
#     365     }
# --> 366     self.async_client = openai.AsyncOpenAI(
#     367         **client_params,
#     368         **async_specific,  # type: ignore[arg-type]
#     369     ).embeddings
#     370 return self
#
# File c:\Users\Pazzucconibt\REPO\llm_engineering\.venv\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.28711770538226206, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.
# 5.0
# 4.0
# 5.0
